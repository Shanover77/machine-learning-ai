# %% [markdown]
# ## Module 5
#
# #### 21 June, 2023
#
# #movie #reviews #stopwords #corpus #nltk

# %% [markdown]
# Topic:1 **Text Classification**

# %%
import nltk
from nltk.corpus import movie_reviews

# %%
nltk.download('movie_reviews')
# Out:
# [nltk_data] Downloading package movie_reviews to
# [nltk_data]     C:\Users\Shanover\AppData\Roaming\nltk_data...
# [nltk_data]   Package movie_reviews is already up-to-date!
# True

# %%
# get categories of the reviews

movie_reviews.categories()
# Out:
# ['neg', 'pos']

# %%
# numbers of reviews

review_ids = movie_reviews.fileids()
num_reviews = len(review_ids)

print("Number of reviews:", num_reviews)
# Out:
# Number of reviews: 2000

# %%
# each categories

neg_r = movie_reviews.fileids('neg')
pos_r = movie_reviews.fileids('pos')


print("Number of positive reviews:", len(pos_r))
print("Number of negative reviews:", len(neg_r))
# Out:
# Number of positive reviews: 1000
# Number of negative reviews: 1000

# %%
# Count overall words, based on categories 'negative(neg)', 'positive(pos)'

review_ids = movie_reviews.fileids()
totalpos = 0
totalneg = 0

for review_id in review_ids:
    category = movie_reviews.categories(review_id)[0]
    words = movie_reviews.words(review_id)
    num_words = len(words)
    
    if category == 'pos':
        totalpos += num_words
    else:
        totalneg += num_words
    
print('Total Pos:', totalpos)
print('Total Neg:', totalneg)
print('Total Words:', totalneg + totalpos)
# Out:
# Total Pos: 832564
# Total Neg: 751256
# Total Words: 1583820

# %% [markdown]
# ## Remove puncations, stopwords

# %%
text = " ".join(movie_reviews.words())
print(len(text))
# Out:
# 7810519

# %%
import string

# %%
text_filtered = text.translate(str.maketrans('','',string.punctuation))

# %% [markdown]
# `string.punctuation` is a string constant provided by the `string` module in Python. It contains all the ASCII punctuation characters like `!"#$%&'()*+,-./:;<=>?@[\]^_{|}~`.
#
# `str.maketrans()` is a method that creates a translation table. It takes three arguments: `x`, `y`, and `z`.
# - `x` is a string containing the characters that need to be replaced.
# - `y` is a string containing the characters that will replace the characters in `x`. If `y` is shorter than `x`, the remaining characters in `x` will be mapped to `None`.
# - `z` is a string containing the characters that need to be deleted (mapped to `None`).
#
# `text.translate()` is a string method that applies the translation table to the given text, replacing or removing characters based on the translation table.

# %%
print('After removing punctuations:', len(text_filtered))
print('Total punctuations removed:', len(text) - len(text_filtered))
# Out:
# After removing punctuations: 7559896
# Total punctuations removed: 250623

# %% [markdown]
# ## remove stopwords in this context

# %%
from nltk.corpus import stopwords

# %%
stop_words = stopwords.words("english")
print('Total stopwords:',len(stop_words))
# Out:
# Total stopwords: 179

# %%
tokens = nltk.word_tokenize(text_filtered)
print('Tokenized length:', len(tokens))
# Out:
# Tokenized length: 1337085

# %%
# make it all lowercase
tokens = [token.lower() for token in tokens]

# remove stopwords
tokens_filtered = [token for token in tokens if token not in stop_words]
print('After removing stopwords:', len(tokens_filtered))
print('Stopwords removed:', len(tokens) - len(tokens_filtered))
# Out:
# After removing stopwords: 708475
# Stopwords removed: 628610

# %% [markdown]
# ### Frequency distribution

# %%
count_dict = nltk.FreqDist(tokens_filtered)
print(count_dict)
# Out:
# <FreqDist with 39295 samples and 708475 outcomes>

# %%
# get them most frequent words

count_dict.most_common(20)
# Out:
# [('film', 9519),
#  ('one', 5853),
#  ('movie', 5774),
#  ('like', 3690),
#  ('even', 2565),
#  ('good', 2411),
#  ('time', 2411),
#  ('story', 2170),
#  ('would', 2110),
#  ('much', 2050),
#  ('character', 2020),
#  ('also', 1967),
#  ('get', 1949),
#  ('two', 1912),
#  ('well', 1906),
#  ('characters', 1859),
#  ('first', 1836),
#  ('see', 1749),
#  ('way', 1693),
#  ('make', 1642)]

# %%
docs = []
for category in movie_reviews.categories():
    for fileid in movie_reviews.fileids(category):
        words = list(movie_reviews.words(fileid))
        doc = (words, category)
        docs.append(doc)

# %%
print('Total docs:', len(docs))
# Out:
# Total docs: 2000

# %%
# return type

print(type(docs[0]))
# Out:
# <class 'tuple'>

# %%
# first document at index 0

print('Category:', docs[0][1],', Content length:',len(docs[0][0]))
# Out:
# Category: neg , Content length: 879

# %%
# each doc category and length
for doc in docs:
    print('Category:', doc[1],', Content length:',len(doc[0]))
# Out:
# Category: neg , Content length: 879
# Category: neg , Content length: 304
# Category: neg , Content length: 581
# Category: neg , Content length: 629
# Category: neg , Content length: 901
# Category: neg , Content length: 759
# Category: neg , Content length: 687
# Category: neg , Content length: 748
# Category: neg , Content length: 854
# Category: neg , Content length: 1025
# Category: neg , Content length: 898
# Category: neg , Content length: 629
# Category: neg , Content length: 568
# Category: neg , Content length: 1144
# Category: neg , Content length: 670
# Category: neg , Content length: 849
# Category: neg , Content length: 780
# Category: neg , Content length: 862
# Category: neg , Content length: 542
# Category: neg , Content length: 885
# Category: neg , Content length: 872
# Category: neg , Content length: 653
# Category: neg , Content length: 801
# Category: neg , Content length: 1315
# Category: neg , Content length: 804
# Category: neg , Content length: 664
# Category: neg , Content length: 600
# Category: neg , Content length: 1503
# Category: neg , Content length: 669
# Category: neg , Content length: 385
# Category: neg , Content length: 564
# Category: neg , Content length: 1026
# Category: neg , Content length: 1492
# Category: neg , Content length: 585
# Category: neg , Content length: 656
# Category: neg , Content length: 683
# Category: neg , Content length: 356
# Category: neg , Content length: 675
# Category: neg , Content length: 860
# Category: neg , Content length: 799
# Category: neg , Content length: 317
# Category: neg , Content length: 675
# Category: neg , Content length: 592
# Category: neg , Content length: 353
# Category: neg , Content length: 653
# Category: neg , Content length: 709
# Category: neg , Content length: 888
# Category: neg , Content length: 841
# Category: neg , Content length: 451
# Category: neg , Content length: 832
# Category: neg , Content length: 650
# Category: neg , Content length: 594
# Category: neg , Content length: 425
# Category: neg , Content length: 1420
# Category: neg , Content length: 821
# Category: neg , Content length: 524
# Category: neg , Content length: 541
# Category: neg , Content length: 239
# Category: neg , Content length: 313
# Category: neg , Content length: 398
# Category: neg , Content length: 534
# Category: neg , Content length: 1432
# Category: neg , Content length: 670
# Category: neg , Content length: 909
# Category: neg , Content length: 709
# Category: neg , Content length: 1233
# Category: neg , Content length: 760
# Category: neg , Content length: 743
# Category: neg , Content length: 545
# Category: neg , Content length: 822
# Category: neg , Content length: 1102
# Category: neg , Content length: 906
# Category: neg , Content length: 891
# Category: neg , Content length: 780
# Category: neg , Content length: 621
# Category: neg , Content length: 402
# Category: neg , Content length: 390
# Category: neg , Content length: 805
# Category: neg , Content length: 724
# Category: neg , Content length: 1348
# Category: neg , Content length: 586
# Category: neg , Content length: 332
# Category: neg , Content length: 497
# Category: neg , Content length: 973
# Category: neg , Content length: 577
# Category: neg , Content length: 644
# Category: neg , Content length: 994
# Category: neg , Content length: 804
# Category: neg , Content length: 404
# Category: neg , Content length: 682
# Category: neg , Content length: 1490
# Category: neg , Content length: 520
# Category: neg , Content length: 684
# Category: neg , Content length: 228
# Category: neg , Content length: 830
# Category: neg , Content length: 498
# Category: neg , Content length: 601
# Category: neg , Content length: 1177
# Category: neg , Content length: 465
# Category: neg , Content length: 811
# Category: neg , Content length: 2114
# Category: neg , Content length: 859
# Category: neg , Content length: 586
# Category: neg , Content length: 913
# Category: neg , Content length: 331
# Category: neg , Content length: 968
# Category: neg , Content length: 387
# Category: neg , Content length: 2271
# Category: neg , Content length: 689
# Category: neg , Content length: 674
# Category: neg , Content length: 387
# Category: neg , Content length: 1165
# Category: neg , Content length: 741
# Category: neg , Content length: 815
# Category: neg , Content length: 277
# Category: neg , Content length: 785
# Category: neg , Content length: 586
# Category: neg , Content length: 449
# Category: neg , Content length: 877
# Category: neg , Content length: 415
# Category: neg , Content length: 840
# Category: neg , Content length: 400
# Category: neg , Content length: 1612
# Category: neg , Content length: 682
# Category: neg , Content length: 937
# Category: neg , Content length: 677
# Category: neg , Content length: 872
# Category: neg , Content length: 706
# Category: neg , Content length: 405
# Category: neg , Content length: 386
# Category: neg , Content length: 428
# Category: neg , Content length: 1408
# Category: neg , Content length: 356
# Category: neg , Content length: 433
# Category: neg , Content length: 857
# Category: neg , Content length: 668
# Category: neg , Content length: 905
# Category: neg , Content length: 632
# Category: neg , Content length: 1434
# Category: neg , Content length: 968
# Category: neg , Content length: 1963
# Category: neg , Content length: 1646
# Category: neg , Content length: 592
# Category: neg , Content length: 580
# Category: neg , Content length: 812
# Category: neg , Content length: 891
# Category: neg , Content length: 818
# Category: neg , Content length: 793
# Category: neg , Content length: 801
# Category: neg , Content length: 641
# Category: neg , Content length: 639
# Category: neg , Content length: 573
# Category: neg , Content length: 601
# Category: neg , Content length: 447
# Category: neg , Content length: 971
# Category: neg , Content length: 601
# Category: neg , Content length: 515
# Category: neg , Content length: 571
# Category: neg , Content length: 634
# Category: neg , Content length: 374
# Category: neg , Content length: 434
# Category: neg , Content length: 963
# Category: neg , Content length: 780
# Category: neg , Content length: 868
# Category: neg , Content length: 651
# Category: neg , Content length: 388
# Category: neg , Content length: 1043
# Category: neg , Content length: 583
# Category: neg , Content length: 484
# Category: neg , Content length: 584
# Category: neg , Content length: 824
# Category: neg , Content length: 280
# Category: neg , Content length: 1146
# Category: neg , Content length: 331
# Category: neg , Content length: 660
# Category: neg , Content length: 718
# Category: neg , Content length: 714
# Category: neg , Content length: 216
# Category: neg , Content length: 647
# Category: neg , Content length: 700
# Category: neg , Content length: 719
# Category: neg , Content length: 510
# Category: neg , Content length: 873
# Category: neg , Content length: 802
# Category: neg , Content length: 489
# Category: neg , Content length: 632
# Category: neg , Content length: 866
# Category: neg , Content length: 1150
# Category: neg , Content length: 727
# Category: neg , Content length: 604
# Category: neg , Content length: 902
# Category: neg , Content length: 753
# Category: neg , Content length: 1064
# Category: neg , Content length: 480
# Category: neg , Content length: 530
# Category: neg , Content length: 717
# Category: neg , Content length: 408
# Category: neg , Content length: 378
# Category: neg , Content length: 685
# Category: neg , Content length: 630
# Category: neg , Content length: 1718
# Category: neg , Content length: 294
# Category: neg , Content length: 907
# Category: neg , Content length: 414
# Category: neg , Content length: 780
# Category: neg , Content length: 267
# Category: neg , Content length: 558
# Category: neg , Content length: 1024
# Category: neg , Content length: 817
# Category: neg , Content length: 677
# Category: neg , Content length: 963
# Category: neg , Content length: 608
# Category: neg , Content length: 735
# Category: neg , Content length: 583
# Category: neg , Content length: 462
# Category: neg , Content length: 616
# Category: neg , Content length: 378
# Category: neg , Content length: 980
# Category: neg , Content length: 319
# Category: neg , Content length: 859
# Category: neg , Content length: 694
# Category: neg , Content length: 769
# Category: neg , Content length: 543
# Category: neg , Content length: 1083
# Category: neg , Content length: 565
# Category: neg , Content length: 853
# Category: neg , Content length: 849
# Category: neg , Content length: 925
# Category: neg , Content length: 909
# Category: neg , Content length: 532
# Category: neg , Content length: 1137
# Category: neg , Content length: 1168
# Category: neg , Content length: 814
# Category: neg , Content length: 532
# Category: neg , Content length: 659
# Category: neg , Content length: 756
# Category: neg , Content length: 707
# Category: neg , Content length: 745
# Category: neg , Content length: 710
# Category: neg , Content length: 381
# Category: neg , Content length: 512
# Category: neg , Content length: 628
# Category: neg , Content length: 491
# Category: neg , Content length: 1133
# Category: neg , Content length: 1316
# Category: neg , Content length: 753
# Category: neg , Content length: 808
# Category: neg , Content length: 361
# Category: neg , Content length: 280
# Category: neg , Content length: 731
# Category: neg , Content length: 1041
# Category: neg , Content length: 939
# Category: neg , Content length: 854
# Category: neg , Content length: 721
# Category: neg , Content length: 753
# Category: neg , Content length: 791
# Category: neg , Content length: 1245
# Category: neg , Content length: 972
# Category: neg , Content length: 503
# Category: neg , Content length: 1138
# Category: neg , Content length: 786
# Category: neg , Content length: 1223
# Category: neg , Content length: 354
# Category: neg , Content length: 902
# Category: neg , Content length: 1132
# Category: neg , Content length: 1177
# Category: neg , Content length: 742
# Category: neg , Content length: 605
# Category: neg , Content length: 509
# Category: neg , Content length: 1557
# Category: neg , Content length: 270
# Category: neg , Content length: 628
# Category: neg , Content length: 917
# Category: neg , Content length: 1018
# Category: neg , Content length: 883
# Category: neg , Content length: 824
# Category: neg , Content length: 1034
# Category: neg , Content length: 504
# Category: neg , Content length: 813
# Category: neg , Content length: 656
# Category: neg , Content length: 560
# Category: neg , Content length: 1337
# Category: neg , Content length: 306
# Category: neg , Content length: 751
# Category: neg , Content length: 605
# Category: neg , Content length: 292
# Category: neg , Content length: 566
# Category: neg , Content length: 632
# Category: neg , Content length: 465
# Category: neg , Content length: 259
# Category: neg , Content length: 504
# Category: neg , Content length: 323
# Category: neg , Content length: 882
# Category: neg , Content length: 648
# Category: neg , Content length: 231
# Category: neg , Content length: 1154
# Category: neg , Content length: 636
# Category: neg , Content length: 695
# Category: neg , Content length: 568
# Category: neg , Content length: 728
# Category: neg , Content length: 1137
# Category: neg , Content length: 629
# Category: neg , Content length: 886
# Category: neg , Content length: 833
# Category: neg , Content length: 607
# Category: neg , Content length: 283
# Category: neg , Content length: 1026
# Category: neg , Content length: 1063
# Category: neg , Content length: 916
# Category: neg , Content length: 608
# Category: neg , Content length: 535
# Category: neg , Content length: 684
# Category: neg , Content length: 752
# Category: neg , Content length: 598
# Category: neg , Content length: 1103
# Category: neg , Content length: 1300
# Category: neg , Content length: 844
# Category: neg , Content length: 661
# Category: neg , Content length: 900
# Category: neg , Content length: 672
# Category: neg , Content length: 670
# Category: neg , Content length: 1103
# Category: neg , Content length: 635
# Category: neg , Content length: 906
# Category: neg , Content length: 509
# Category: neg , Content length: 660
# Category: neg , Content length: 306
# Category: neg , Content length: 826
# Category: neg , Content length: 506
# Category: neg , Content length: 183
# Category: neg , Content length: 664
# Category: neg , Content length: 777
# Category: neg , Content length: 506
# Category: neg , Content length: 743
# Category: neg , Content length: 977
# Category: neg , Content length: 884
# Category: neg , Content length: 852
# Category: neg , Content length: 486
# Category: neg , Content length: 1000
# Category: neg , Content length: 576
# Category: neg , Content length: 320
# Category: neg , Content length: 838
# Category: neg , Content length: 527
# Category: neg , Content length: 210
# Category: neg , Content length: 492
# Category: neg , Content length: 724
# Category: neg , Content length: 854
# Category: neg , Content length: 330
# Category: neg , Content length: 904
# Category: neg , Content length: 1127
# Category: neg , Content length: 481
# Category: neg , Content length: 616
# Category: neg , Content length: 463
# Category: neg , Content length: 881
# Category: neg , Content length: 398
# Category: neg , Content length: 298
# Category: neg , Content length: 1557
# Category: neg , Content length: 369
# Category: neg , Content length: 1104
# Category: neg , Content length: 1143
# Category: neg , Content length: 589
# Category: neg , Content length: 950
# Category: neg , Content length: 649
# Category: neg , Content length: 390
# Category: neg , Content length: 1069
# Category: neg , Content length: 1180
# Category: neg , Content length: 674
# Category: neg , Content length: 1617
# Category: neg , Content length: 1104
# Category: neg , Content length: 920
# Category: neg , Content length: 482
# Category: neg , Content length: 551
# Category: neg , Content length: 546
# Category: neg , Content length: 975
# Category: neg , Content length: 633
# Category: neg , Content length: 587
# Category: neg , Content length: 773
# Category: neg , Content length: 239
# Category: neg , Content length: 938
# Category: neg , Content length: 1002
# Category: neg , Content length: 565
# Category: neg , Content length: 816
# Category: neg , Content length: 419
# Category: neg , Content length: 583
# Category: neg , Content length: 654
# Category: neg , Content length: 489
# Category: neg , Content length: 562
# Category: neg , Content length: 511
# Category: neg , Content length: 469
# Category: neg , Content length: 618
# Category: neg , Content length: 561
# Category: neg , Content length: 925
# Category: neg , Content length: 871
# Category: neg , Content length: 575
# Category: neg , Content length: 1023
# Category: neg , Content length: 534
# Category: neg , Content length: 239
# Category: neg , Content length: 605
# Category: neg , Content length: 486
# Category: neg , Content length: 657
# Category: neg , Content length: 512
# Category: neg , Content length: 1258
# Category: neg , Content length: 1249
# Category: neg , Content length: 916
# Category: neg , Content length: 482
# Category: neg , Content length: 670
# Category: neg , Content length: 781
# Category: neg , Content length: 785
# Category: neg , Content length: 532
# Category: neg , Content length: 598
# Category: neg , Content length: 492
# Category: neg , Content length: 511
# Category: neg , Content length: 1513
# Category: neg , Content length: 853
# Category: neg , Content length: 911
# Category: neg , Content length: 1082
# Category: neg , Content length: 996
# Category: neg , Content length: 690
# Category: neg , Content length: 838
# Category: neg , Content length: 986
# Category: neg , Content length: 813
# Category: neg , Content length: 759
# Category: neg , Content length: 647
# Category: neg , Content length: 1213
# Category: neg , Content length: 1422
# Category: neg , Content length: 1068
# Category: neg , Content length: 733
# Category: neg , Content length: 1512
# Category: neg , Content length: 2231
# Category: neg , Content length: 589
# Category: neg , Content length: 628
# Category: neg , Content length: 257
# Category: neg , Content length: 664
# Category: neg , Content length: 903
# Category: neg , Content length: 875
# Category: neg , Content length: 142
# Category: neg , Content length: 808
# Category: neg , Content length: 1033
# Category: neg , Content length: 687
# Category: neg , Content length: 552
# Category: neg , Content length: 241
# Category: neg , Content length: 1235
# Category: neg , Content length: 1259
# Category: neg , Content length: 611
# Category: neg , Content length: 456
# Category: neg , Content length: 751
# Category: neg , Content length: 626
# Category: neg , Content length: 406
# Category: neg , Content length: 442
# Category: neg , Content length: 821
# Category: neg , Content length: 225
# Category: neg , Content length: 794
# Category: neg , Content length: 289
# Category: neg , Content length: 940
# Category: neg , Content length: 891
# Category: neg , Content length: 575
# Category: neg , Content length: 793
# Category: neg , Content length: 842
# Category: neg , Content length: 787
# Category: neg , Content length: 1144
# Category: neg , Content length: 311
# Category: neg , Content length: 491
# Category: neg , Content length: 801
# Category: neg , Content length: 523
# Category: neg , Content length: 1015
# Category: neg , Content length: 754
# Category: neg , Content length: 535
# Category: neg , Content length: 728
# Category: neg , Content length: 687
# Category: neg , Content length: 990
# Category: neg , Content length: 762
# Category: neg , Content length: 748
# Category: neg , Content length: 868
# Category: neg , Content length: 933
# Category: neg , Content length: 423
# Category: neg , Content length: 1099
# Category: neg , Content length: 598
# Category: neg , Content length: 248
# Category: neg , Content length: 1430
# Category: neg , Content length: 951
# Category: neg , Content length: 823
# Category: neg , Content length: 439
# Category: neg , Content length: 825
# Category: neg , Content length: 483
# Category: neg , Content length: 1289
# Category: neg , Content length: 1595
# Category: neg , Content length: 957
# Category: neg , Content length: 656
# Category: neg , Content length: 673
# Category: neg , Content length: 1409
# Category: neg , Content length: 757
# Category: neg , Content length: 873
# Category: neg , Content length: 511
# Category: neg , Content length: 650
# Category: neg , Content length: 1036
# Category: neg , Content length: 673
# Category: neg , Content length: 523
# Category: neg , Content length: 628
# Category: neg , Content length: 339
# Category: neg , Content length: 1066
# Category: neg , Content length: 664
# Category: neg , Content length: 1158
# Category: neg , Content length: 821
# Category: neg , Content length: 662
# Category: neg , Content length: 587
# Category: neg , Content length: 943
# Category: neg , Content length: 19
# Category: neg , Content length: 906
# Category: neg , Content length: 396
# Category: neg , Content length: 464
# Category: neg , Content length: 497
# Category: neg , Content length: 1437
# Category: neg , Content length: 690
# Category: neg , Content length: 707
# Category: neg , Content length: 1196
# Category: neg , Content length: 291
# Category: neg , Content length: 703
# Category: neg , Content length: 824
# Category: neg , Content length: 628
# Category: neg , Content length: 243
# Category: neg , Content length: 823
# Category: neg , Content length: 576
# Category: neg , Content length: 434
# Category: neg , Content length: 554
# Category: neg , Content length: 1392
# Category: neg , Content length: 612
# Category: neg , Content length: 1818
# Category: neg , Content length: 831
# Category: neg , Content length: 546
# Category: neg , Content length: 933
# Category: neg , Content length: 611
# Category: neg , Content length: 830
# Category: neg , Content length: 294
# Category: neg , Content length: 1100
# Category: neg , Content length: 657
# Category: neg , Content length: 619
# Category: neg , Content length: 933
# Category: neg , Content length: 674
# Category: neg , Content length: 715
# Category: neg , Content length: 953
# Category: neg , Content length: 1005
# Category: neg , Content length: 514
# Category: neg , Content length: 705
# Category: neg , Content length: 497
# Category: neg , Content length: 747
# Category: neg , Content length: 507
# Category: neg , Content length: 517
# Category: neg , Content length: 491
# Category: neg , Content length: 787
# Category: neg , Content length: 672
# Category: neg , Content length: 826
# Category: neg , Content length: 1064
# Category: neg , Content length: 1068
# Category: neg , Content length: 780
# Category: neg , Content length: 944
# Category: neg , Content length: 405
# Category: neg , Content length: 704
# Category: neg , Content length: 811
# Category: neg , Content length: 362
# Category: neg , Content length: 611
# Category: neg , Content length: 867
# Category: neg , Content length: 805
# Category: neg , Content length: 890
# Category: neg , Content length: 230
# Category: neg , Content length: 931
# Category: neg , Content length: 828
# Category: neg , Content length: 741
# Category: neg , Content length: 805
# Category: neg , Content length: 975
# Category: neg , Content length: 1080
# Category: neg , Content length: 789
# Category: neg , Content length: 1039
# Category: neg , Content length: 714
# Category: neg , Content length: 351
# Category: neg , Content length: 1178
# Category: neg , Content length: 822
# Category: neg , Content length: 892
# Category: neg , Content length: 510
# Category: neg , Content length: 263
# Category: neg , Content length: 994
# Category: neg , Content length: 688
# Category: neg , Content length: 746
# Category: neg , Content length: 493
# Category: neg , Content length: 408
# Category: neg , Content length: 415
# Category: neg , Content length: 724
# Category: neg , Content length: 1184
# Category: neg , Content length: 700
# Category: neg , Content length: 559
# Category: neg , Content length: 518
# Category: neg , Content length: 830
# Category: neg , Content length: 542
# Category: neg , Content length: 1369
# Category: neg , Content length: 793
# Category: neg , Content length: 827
# Category: neg , Content length: 940
# Category: neg , Content length: 469
# Category: neg , Content length: 1517
# Category: neg , Content length: 433
# Category: neg , Content length: 579
# Category: neg , Content length: 338
# Category: neg , Content length: 603
# Category: neg , Content length: 510
# Category: neg , Content length: 314
# Category: neg , Content length: 563
# Category: neg , Content length: 555
# Category: neg , Content length: 608
# Category: neg , Content length: 707
# Category: neg , Content length: 819
# Category: neg , Content length: 1464
# Category: neg , Content length: 984
# Category: neg , Content length: 373
# Category: neg , Content length: 770
# Category: neg , Content length: 663
# Category: neg , Content length: 1162
# Category: neg , Content length: 792
# Category: neg , Content length: 354
# Category: neg , Content length: 776
# Category: neg , Content length: 597
# Category: neg , Content length: 1241
# Category: neg , Content length: 771
# Category: neg , Content length: 1263
# Category: neg , Content length: 918
# Category: neg , Content length: 1908
# Category: neg , Content length: 752
# Category: neg , Content length: 928
# Category: neg , Content length: 838
# Category: neg , Content length: 384
# Category: neg , Content length: 1090
# Category: neg , Content length: 621
# Category: neg , Content length: 928
# Category: neg , Content length: 511
# Category: neg , Content length: 545
# Category: neg , Content length: 697
# Category: neg , Content length: 887
# Category: neg , Content length: 1032
# Category: neg , Content length: 901
# Category: neg , Content length: 1000
# Category: neg , Content length: 775
# Category: neg , Content length: 1077
# Category: neg , Content length: 598
# Category: neg , Content length: 1167
# Category: neg , Content length: 575
# Category: neg , Content length: 840
# Category: neg , Content length: 409
# Category: neg , Content length: 1049
# Category: neg , Content length: 1203
# Category: neg , Content length: 893
# Category: neg , Content length: 705
# Category: neg , Content length: 736
# Category: neg , Content length: 451
# Category: neg , Content length: 680
# Category: neg , Content length: 944
# Category: neg , Content length: 818
# Category: neg , Content length: 1316
# Category: neg , Content length: 614
# Category: neg , Content length: 1509
# Category: neg , Content length: 511
# Category: neg , Content length: 562
# Category: neg , Content length: 920
# Category: neg , Content length: 724
# Category: neg , Content length: 593
# Category: neg , Content length: 399
# Category: neg , Content length: 829
# Category: neg , Content length: 465
# Category: neg , Content length: 362
# Category: neg , Content length: 625
# Category: neg , Content length: 404
# Category: neg , Content length: 681
# Category: neg , Content length: 1060
# Category: neg , Content length: 468
# Category: neg , Content length: 197
# Category: neg , Content length: 528
# Category: neg , Content length: 675
# Category: neg , Content length: 324
# Category: neg , Content length: 783
# Category: neg , Content length: 1247
# Category: neg , Content length: 999
# Category: neg , Content length: 302
# Category: neg , Content length: 458
# Category: neg , Content length: 924
# Category: neg , Content length: 788
# Category: neg , Content length: 678
# Category: neg , Content length: 989
# Category: neg , Content length: 863
# Category: neg , Content length: 647
# Category: neg , Content length: 776
# Category: neg , Content length: 683
# Category: neg , Content length: 778
# Category: neg , Content length: 571
# Category: neg , Content length: 1690
# Category: neg , Content length: 970
# Category: neg , Content length: 607
# Category: neg , Content length: 542
# Category: neg , Content length: 342
# Category: neg , Content length: 691
# Category: neg , Content length: 925
# Category: neg , Content length: 813
# Category: neg , Content length: 855
# Category: neg , Content length: 760
# Category: neg , Content length: 660
# Category: neg , Content length: 759
# Category: neg , Content length: 516
# Category: neg , Content length: 544
# Category: neg , Content length: 720
# Category: neg , Content length: 588
# Category: neg , Content length: 755
# Category: neg , Content length: 500
# Category: neg , Content length: 562
# Category: neg , Content length: 1170
# Category: neg , Content length: 686
# Category: neg , Content length: 990
# Category: neg , Content length: 622
# Category: neg , Content length: 1261
# Category: neg , Content length: 932
# Category: neg , Content length: 668
# Category: neg , Content length: 475
# Category: neg , Content length: 582
# Category: neg , Content length: 993
# Category: neg , Content length: 1126
# Category: neg , Content length: 357
# Category: neg , Content length: 735
# Category: neg , Content length: 607
# Category: neg , Content length: 889
# Category: neg , Content length: 525
# Category: neg , Content length: 798
# Category: neg , Content length: 556
# Category: neg , Content length: 615
# Category: neg , Content length: 449
# Category: neg , Content length: 786
# Category: neg , Content length: 1035
# Category: neg , Content length: 437
# Category: neg , Content length: 2339
# Category: neg , Content length: 709
# Category: neg , Content length: 701
# Category: neg , Content length: 822
# Category: neg , Content length: 1231
# Category: neg , Content length: 416
# Category: neg , Content length: 801
# Category: neg , Content length: 525
# Category: neg , Content length: 532
# Category: neg , Content length: 705
# Category: neg , Content length: 563
# Category: neg , Content length: 595
# Category: neg , Content length: 888
# Category: neg , Content length: 1117
# Category: neg , Content length: 1921
# Category: neg , Content length: 624
# Category: neg , Content length: 601
# Category: neg , Content length: 1001
# Category: neg , Content length: 519
# Category: neg , Content length: 779
# Category: neg , Content length: 483
# Category: neg , Content length: 813
# Category: neg , Content length: 718
# Category: neg , Content length: 1149
# Category: neg , Content length: 762
# Category: neg , Content length: 656
# Category: neg , Content length: 982
# Category: neg , Content length: 940
# Category: neg , Content length: 1114
# Category: neg , Content length: 1185
# Category: neg , Content length: 940
# Category: neg , Content length: 692
# Category: neg , Content length: 411
# Category: neg , Content length: 789
# Category: neg , Content length: 1291
# Category: neg , Content length: 998
# Category: neg , Content length: 942
# Category: neg , Content length: 590
# Category: neg , Content length: 1007
# Category: neg , Content length: 901
# Category: neg , Content length: 1158
# Category: neg , Content length: 988
# Category: neg , Content length: 638
# Category: neg , Content length: 765
# Category: neg , Content length: 768
# Category: neg , Content length: 972
# Category: neg , Content length: 561
# Category: neg , Content length: 116
# Category: neg , Content length: 501
# Category: neg , Content length: 909
# Category: neg , Content length: 655
# Category: neg , Content length: 401
# Category: neg , Content length: 1083
# Category: neg , Content length: 560
# Category: neg , Content length: 362
# Category: neg , Content length: 1893
# Category: neg , Content length: 1201
# Category: neg , Content length: 666
# Category: neg , Content length: 631
# Category: neg , Content length: 573
# Category: neg , Content length: 400
# Category: neg , Content length: 335
# Category: neg , Content length: 341
# Category: neg , Content length: 642
# Category: neg , Content length: 688
# Category: neg , Content length: 828
# Category: neg , Content length: 704
# Category: neg , Content length: 1255
# Category: neg , Content length: 723
# Category: neg , Content length: 344
# Category: neg , Content length: 497
# Category: neg , Content length: 1106
# Category: neg , Content length: 508
# Category: neg , Content length: 794
# Category: neg , Content length: 460
# Category: neg , Content length: 1844
# Category: neg , Content length: 514
# Category: neg , Content length: 263
# Category: neg , Content length: 717
# Category: neg , Content length: 1029
# Category: neg , Content length: 631
# Category: neg , Content length: 1040
# Category: neg , Content length: 453
# Category: neg , Content length: 1485
# Category: neg , Content length: 771
# Category: neg , Content length: 309
# Category: neg , Content length: 1026
# Category: neg , Content length: 761
# Category: neg , Content length: 1043
# Category: neg , Content length: 596
# Category: neg , Content length: 681
# Category: neg , Content length: 621
# Category: neg , Content length: 573
# Category: neg , Content length: 553
# Category: neg , Content length: 1080
# Category: neg , Content length: 384
# Category: neg , Content length: 376
# Category: neg , Content length: 905
# Category: neg , Content length: 277
# Category: neg , Content length: 1024
# Category: neg , Content length: 1262
# Category: neg , Content length: 832
# Category: neg , Content length: 1379
# Category: neg , Content length: 886
# Category: neg , Content length: 536
# Category: neg , Content length: 782
# Category: neg , Content length: 903
# Category: neg , Content length: 702
# Category: neg , Content length: 406
# Category: neg , Content length: 824
# Category: neg , Content length: 912
# Category: neg , Content length: 356
# Category: neg , Content length: 934
# Category: neg , Content length: 730
# Category: neg , Content length: 868
# Category: neg , Content length: 992
# Category: neg , Content length: 696
# Category: neg , Content length: 1100
# Category: neg , Content length: 592
# Category: neg , Content length: 638
# Category: neg , Content length: 850
# Category: neg , Content length: 669
# Category: neg , Content length: 287
# Category: neg , Content length: 449
# Category: neg , Content length: 430
# Category: neg , Content length: 131
# Category: neg , Content length: 913
# Category: neg , Content length: 564
# Category: neg , Content length: 634
# Category: neg , Content length: 363
# Category: neg , Content length: 837
# Category: neg , Content length: 586
# Category: neg , Content length: 788
# Category: neg , Content length: 1006
# Category: neg , Content length: 700
# Category: neg , Content length: 829
# Category: neg , Content length: 289
# Category: neg , Content length: 839
# Category: neg , Content length: 460
# Category: neg , Content length: 1610
# Category: neg , Content length: 797
# Category: neg , Content length: 620
# Category: neg , Content length: 1217
# Category: neg , Content length: 179
# Category: neg , Content length: 845
# Category: neg , Content length: 749
# Category: neg , Content length: 837
# Category: neg , Content length: 484
# Category: neg , Content length: 421
# Category: neg , Content length: 324
# Category: neg , Content length: 885
# Category: neg , Content length: 981
# Category: neg , Content length: 582
# Category: neg , Content length: 550
# Category: neg , Content length: 680
# Category: neg , Content length: 281
# Category: neg , Content length: 950
# Category: neg , Content length: 986
# Category: neg , Content length: 832
# Category: neg , Content length: 961
# Category: neg , Content length: 890
# Category: neg , Content length: 1895
# Category: neg , Content length: 675
# Category: neg , Content length: 404
# Category: neg , Content length: 646
# Category: neg , Content length: 492
# Category: neg , Content length: 578
# Category: neg , Content length: 448
# Category: neg , Content length: 632
# Category: neg , Content length: 397
# Category: neg , Content length: 847
# Category: neg , Content length: 361
# Category: neg , Content length: 266
# Category: neg , Content length: 733
# Category: neg , Content length: 965
# Category: neg , Content length: 765
# Category: neg , Content length: 1053
# Category: neg , Content length: 449
# Category: neg , Content length: 711
# Category: neg , Content length: 978
# Category: neg , Content length: 1322
# Category: neg , Content length: 501
# Category: neg , Content length: 535
# Category: neg , Content length: 638
# Category: neg , Content length: 605
# Category: neg , Content length: 755
# Category: neg , Content length: 710
# Category: neg , Content length: 514
# Category: neg , Content length: 380
# Category: neg , Content length: 1064
# Category: neg , Content length: 383
# Category: neg , Content length: 913
# Category: neg , Content length: 659
# Category: neg , Content length: 590
# Category: neg , Content length: 1761
# Category: neg , Content length: 971
# Category: neg , Content length: 1392
# Category: neg , Content length: 342
# Category: neg , Content length: 543
# Category: neg , Content length: 471
# Category: neg , Content length: 525
# Category: neg , Content length: 1657
# Category: neg , Content length: 1073
# Category: neg , Content length: 994
# Category: neg , Content length: 624
# Category: neg , Content length: 603
# Category: neg , Content length: 644
# Category: neg , Content length: 533
# Category: neg , Content length: 201
# Category: neg , Content length: 821
# Category: neg , Content length: 806
# Category: neg , Content length: 558
# Category: neg , Content length: 783
# Category: neg , Content length: 613
# Category: neg , Content length: 799
# Category: neg , Content length: 348
# Category: neg , Content length: 722
# Category: neg , Content length: 953
# Category: neg , Content length: 1619
# Category: neg , Content length: 983
# Category: pos , Content length: 428
# Category: pos , Content length: 948
# Category: pos , Content length: 1092
# Category: pos , Content length: 2157
# Category: pos , Content length: 752
# Category: pos , Content length: 470
# Category: pos , Content length: 1012
# Category: pos , Content length: 644
# Category: pos , Content length: 668
# Category: pos , Content length: 754
# Category: pos , Content length: 1048
# Category: pos , Content length: 549
# Category: pos , Content length: 1128
# Category: pos , Content length: 938
# Category: pos , Content length: 597
# Category: pos , Content length: 795
# Category: pos , Content length: 481
# Category: pos , Content length: 1075
# Category: pos , Content length: 601
# Category: pos , Content length: 623
# Category: pos , Content length: 903
# Category: pos , Content length: 1099
# Category: pos , Content length: 647
# Category: pos , Content length: 760
# Category: pos , Content length: 1442
# Category: pos , Content length: 812
# Category: pos , Content length: 669
# Category: pos , Content length: 773
# Category: pos , Content length: 724
# Category: pos , Content length: 670
# Category: pos , Content length: 1414
# Category: pos , Content length: 630
# Category: pos , Content length: 1124
# Category: pos , Content length: 284
# Category: pos , Content length: 535
# Category: pos , Content length: 955
# Category: pos , Content length: 1016
# Category: pos , Content length: 557
# Category: pos , Content length: 890
# Category: pos , Content length: 688
# Category: pos , Content length: 960
# Category: pos , Content length: 696
# Category: pos , Content length: 787
# Category: pos , Content length: 1373
# Category: pos , Content length: 238
# Category: pos , Content length: 1069
# Category: pos , Content length: 938
# Category: pos , Content length: 1233
# Category: pos , Content length: 729
# Category: pos , Content length: 1696
# Category: pos , Content length: 819
# Category: pos , Content length: 642
# Category: pos , Content length: 889
# Category: pos , Content length: 386
# Category: pos , Content length: 1232
# Category: pos , Content length: 704
# Category: pos , Content length: 1190

# %% [markdown]
# ## Feature Extraction

# %%
word_features = [w[0] for w in count_dict.most_common(3000)]
# word_features = [w[0] for w in count_dict.most_common(60)]
# word_features = newWords

# %%
def search_features(doc):
    words = set(doc)
    features = {}
    for w in word_features:
        features[w] = (w in words)
    return features

# %% [markdown]
# ### searching and checking for the match

# %%
match = search_features(docs[0][0])

totalTrue = 0
totalFalse = 0

for key,value in match.items():    
    if value==True:
        totalTrue = totalTrue + 1
    else:
        totalFalse = totalFalse + 1
        
print('True:',totalTrue)
print('False:',totalFalse)
# Out:
# True: 204
# False: 2796

# %%
docs[100][::-1] # Notice the 'neg' category at the end of every doc in docs-list
# Out:
# ('neg',
#  ['warning',
#   ':',
#   'spoilers',
#   'are',
#   'included',
#   'in',
#   'this',
#   'review',
#   '.',
#   '.',
#   '.',
#   'but',
#   'it',
#   'doesn',
#   "'",
#   't',
#   'really',
#   'make',
#   'much',
#   'of',
#   'a',
#   'difference',
#   '.',
#   'deep',
#   'impact',
#   'begins',
#   'the',
#   'official',
#   'summer',
#   'movie',
#   'season',
#   ',',
#   'and',
#   'it',
#   'also',
#   'brings',
#   'back',
#   'memories',
#   'of',
#   '1997',
#   '.',
#   'remember',
#   'when',
#   'dante',
#   "'",
#   's',
#   'peak',
#   'came',
#   'out',
#   'in',
#   'february',
#   '?',
#   'a',
#   'few',
#   'months',
#   'later',
#   ',',
#   'volcano',
#   'was',
#   'released',
#   '.',
#   'the',
#   'first',
#   'film',
#   'was',
#   'smart',
#   ',',
#   'exhilirating',
#   ',',
#   'and',
#   'one',
#   'of',
#   'the',
#   'best',
#   'disaster',
#   'films',
#   'i',
#   'had',
#   'ever',
#   'seen',
#   '.',
#   'the',
#   'latter',
#   'film',
#   'was',
#   'an',
#   'incohesive',
#   'mess',
#   'that',
#   'defied',
#   'logic',
#   'and',
#   'wasted',
#   'talent',
#   '.',
#   'well',
#   ',',
#   'it',
#   "'",
#   's',
#   'deja',
#   'vu',
#   'all',
#   'over',
#   'again',
#   'as',
#   'two',
#   'disaster',
#   'films',
#   'go',
#   'head',
#   'to',
#   'head',
#   'in',
#   'competition',
#   '.',
#   'this',
#   'time',
#   ',',
#   'unfortunately',
#   ',',
#   'the',
#   'first',
#   'comet',
#   'flick',
#   'is',
#   'so',
#   'bad',
#   'that',
#   'people',
#   'may',
#   'shy',
#   'away',
#   'from',
#   'armageddon',
#   ',',
#   'the',
#   'upcoming',
#   'comet',
#   '-',
#   'disaster',
#   'to',
#   'be',
#   'released',
#   'the',
#   'beginning',
#   'of',
#   'july',
#   '.',
#   'of',
#   'course',
#   ',',
#   'the',
#   'general',
#   'reaction',
#   'of',
#   'the',
#   'audience',
#   'was',
#   'oppposed',
#   'to',
#   'mine',
#   ',',
#   'and',
#   'so',
#   'i',
#   'am',
#   'in',
#   'the',
#   'minority',
#   ',',
#   'as',
#   'i',
#   'was',
#   'when',
#   'i',
#   'stood',
#   'on',
#   'the',
#   'side',
#   'of',
#   'dante',
#   "'",
#   's',
#   'peak',
#   '.',
#   'but',
#   'while',
#   'watching',
#   'deep',
#   'impact',
#   ',',
#   'i',
#   'began',
#   'to',
#   'wonder',
#   'how',
#   'anyone',
#   'in',
#   'their',
#   'right',
#   'mind',
#   'could',
#   'actually',
#   'like',
#   'this',
#   'film',
#   '.',
#   'apparently',
#   'many',
#   'did',
#   ',',
#   'and',
#   'it',
#   'utterly',
#   'baffles',
#   'me',
#   '.',
#   'to',
#   'be',
#   'completely',
#   'honest',
#   ',',
#   'i',
#   'haven',
#   "'",
#   't',
#   'had',
#   'this',
#   'little',
#   'fun',
#   'watching',
#   'a',
#   'disaster',
#   'film',
#   'in',
#   'my',
#   'entire',
#   'life',
#   '.',
#   'volcano',
#   'had',
#   'implausibilities',
#   'up',
#   'the',
#   'wazoo',
#   ',',
#   'but',
#   'it',
#   'was',
#   'still',
#   'rather',
#   'fun',
#   'to',
#   'watch',
#   '.',
#   'deep',
#   'impact',
#   'doesn',
#   "'",
#   't',
#   'just',
#   'have',
#   'implausibilities',
#   ',',
#   'it',
#   'also',
#   'contains',
#   'cheap',
#   'human',
#   'drama',
#   ',',
#   'incredibly',
#   'horrible',
#   'special',
#   'effects',
#   ',',
#   'and',
#   'a',
#   'poorly',
#   'constructed',
#   'plot',
#   '.',
#   'the',
#   'only',
#   'thing',
#   'that',
#   'gives',
#   'it',
#   'a',
#   'half',
#   'star',
#   'above',
#   'my',
#   'bottom',
#   'ranking',
#   'is',
#   'a',
#   'slightly',
#   'entertaining',
#   'final',
#   'fifteen',
#   'minutes',
#   'and',
#   'some',
#   'good',
#   'actors',
#   'making',
#   'the',
#   'most',
#   'of',
#   'their',
#   'characters',
#   '.',
#   'deep',
#   'impact',
#   'begins',
#   'in',
#   'an',
#   'unnamed',
#   'year',
#   '(',
#   'the',
#   'year',
#   'varies',
#   ';',
#   'advanced',
#   'technology',
#   'sets',
#   'it',
#   'in',
#   'the',
#   'future',
#   ',',
#   'but',
#   'fire',
#   'in',
#   'the',
#   'sky',
#   'is',
#   'showing',
#   'on',
#   'a',
#   'local',
#   'movie',
#   'theater',
#   ',',
#   'pushing',
#   'it',
#   'back',
#   'to',
#   '1993',
#   ')',
#   '.',
#   'a',
#   'line',
#   'of',
#   'students',
#   'is',
#   'outside',
#   'at',
#   'night',
#   ',',
#   'peering',
#   'through',
#   'telescopes',
#   'at',
#   'the',
#   'dark',
#   'sky',
#   'above',
#   '.',
#   'among',
#   'these',
#   'are',
#   'leo',
#   'biederman',
#   '(',
#   'elijah',
#   'wood',
#   ')',
#   'and',
#   'sarah',
#   'hotchner',
#   '(',
#   'leelee',
#   'sobieski',
#   ')',
#   '.',
#   'leo',
#   'unknowingly',
#   'discovers',
#   'a',
#   'comet',
#   ',',
#   'and',
#   'his',
#   'teacher',
#   'sends',
#   'a',
#   'photo',
#   'of',
#   'the',
#   'unknown',
#   'object',
#   'to',
#   'an',
#   'astronomer',
#   ',',
#   'who',
#   'then',
#   'is',
#   'able',
#   'to',
#   'determine',
#   'the',
#   'correct',
#   'path',
#   'of',
#   'this',
#   'distant',
#   'comet',
#   'in',
#   'about',
#   'a',
#   'few',
#   'seconds',
#   '.',
#   'he',
#   'races',
#   'off',
#   'to',
#   'mail',
#   'the',
#   'information',
#   ',',
#   'but',
#   'is',
#   'killed',
#   'in',
#   'a',
#   'reckless',
#   'car',
#   'accident',
#   '.',
#   'a',
#   'year',
#   'passes',
#   ',',
#   'and',
#   'nothing',
#   'is',
#   'heard',
#   'about',
#   'it',
#   'again',
#   '.',
#   'we',
#   'are',
#   'then',
#   'introduced',
#   'to',
#   'jenny',
#   'lerner',
#   '(',
#   't',
#   '?',
#   'a',
#   'leoni',
#   ')',
#   ',',
#   'a',
#   'reporter',
#   'for',
#   'msnbc',
#   '.',
#   'she',
#   'gets',
#   'handed',
#   'a',
#   'job',
#   'to',
#   'investigate',
#   'a',
#   'possible',
#   'cover',
#   '-',
#   'up',
#   'in',
#   'the',
#   'government',
#   'involving',
#   'senator',
#   'alan',
#   'rittenhouse',
#   '(',
#   'james',
#   'cromwell',
#   ')',
#   '.',
#   'she',
#   'talks',
#   'to',
#   'a',
#   'woman',
#   'who',
#   'mentions',
#   'that',
#   'rittenhouse',
#   'was',
#   'having',
#   'an',
#   'affair',
#   'with',
#   'a',
#   'girl',
#   'named',
#   'ellie',
#   '.',
#   'after',
#   'talking',
#   'with',
#   'rittenhouse',
#   ',',
#   'and',
#   'unsatisfied',
#   'with',
#   'the',
#   'information',
#   'she',
#   'gets',
#   ',',
#   'she',
#   'decides',
#   'to',
#   'use',
#   'the',
#   'internet',
#   'for',
#   'help',
#   '.',
#   'luckily',
#   ',',
#   'she',
#   'knows',
#   'exactly',
#   'how',
#   'to',
#   'spell',
#   'the',
#   'certain',
#   '"',
#   'ellie',
#   '"',
#   'that',
#   'she',
#   'is',
#   'looking',
#   'for',
#   '(',
#   'they',
#   'spell',
#   'it',
#   'ele',
#   'in',
#   'the',
#   'film',
#   '.',
#   '.',
#   '.',
#   'that',
#   'girl',
#   'is',
#   'pretty',
#   'darn',
#   'smart',
#   'for',
#   'guessing',
#   'how',
#   'it',
#   'was',
#   'spelled',
#   ')',
#   '.',
#   'before',
#   'she',
#   'can',
#   'use',
#   'the',
#   'information',
#   ',',
#   'the',
#   'government',
#   'decides',
#   'to',
#   'push',
#   'her',
#   'car',
#   'off',
#   'the',
#   'road',
#   '.',
#   'they',
#   'take',
#   'her',
#   'in',
#   'to',
#   'meet',
#   'the',
#   'president',
#   'of',
#   'the',
#   'united',
#   'states',
#   ',',
#   'president',
#   'beck',
#   '(',
#   'morgan',
#   'freeman',
#   ')',
#   '.',
#   'beck',
#   'recommends',
#   'that',
#   'jenny',
#   'keep',
#   'the',
#   'information',
#   'secret',
#   'for',
#   '48',
#   'hours',
#   'so',
#   'they',
#   'can',
#   'confirm',
#   'it',
#   'and',
#   'then',
#   'hold',
#   'a',
#   'press',
#   'conference',
#   '.',
#   'naturally',
#   ',',
#   'she',
#   'wants',
#   'to',
#   'be',
#   'compensated',
#   ',',
#   'and',
#   'they',
#   'offer',
#   'her',
#   'a',
#   'front',
#   'row',
#   'seat',
#   'and',
#   'the',
#   'chance',
#   'for',
#   'the',
#   'first',
#   'question',
#   '.',
#   'and',
#   'so',
#   ',',
#   'yada',
#   'yada',
#   'yada',
#   ',',
#   'they',
#   'reveal',
#   'the',
#   'comet',
#   'to',
#   'the',
#   'public',
#   'and',
#   'their',
#   'plans',
#   ':',
#   'send',
#   'a',
#   'massive',
#   'spacecraft',
#   'out',
#   'to',
#   'destroy',
#   'it',
#   'before',
#   'it',
#   'can',
#   'arrive',
#   '.',
#   'they',
#   'announce',
#   'a',
#   'plan',
#   'called',
#   '"',
#   'ark',
#   ',',
#   '"',
#   'which',
#   'is',
#   'their',
#   'only',
#   'hope',
#   'for',
#   'survival',
#   '.',
#   'a',
#   'computer',
#   'will',
#   'select',
#   '800',
#   ',',
#   '000',
#   'people',
#   'at',
#   'random',
#   '.',
#   'these',
#   'people',
#   'are',
#   'the',
#   'ones',
#   'who',
#   'will',
#   'go',
#   'into',
#   'a',
#   'large',
#   'cave',
#   'underground',
#   'so',
#   'that',
#   'the',
#   'impact',
#   'of',
#   'the',
#   'comet',
#   'won',
#   "'",
#   't',
#   'kill',
#   'off',
#   'the',
#   'entire',
#   'human',
#   'race',
#   '.',
#   'after',
#   'two',
#   'years',
#   ',',
#   'the',
#   'dust',
#   'will',
#   'settle',
#   '(',
#   'actually',
#   ',',
#   'it',
#   'would',
#   'take',
#   'much',
#   ',',
#   'much',
#   'longer',
#   '--',
#   'approximately',
#   'ninety',
#   'years',
#   ',',
#   'from',
#   'what',
#   'i',
#   'understand',
#   ')',
#   'and',
#   'the',
#   'humans',
#   'could',
#   'come',
#   'back',
#   'to',
#   'the',
#   'surface',
#   'and',
#   'start',
#   'over',
#   '.',
#   'the',
#   'rest',
#   'of',
#   'the',
#   'plot',
#   'is',
#   'your',
#   'standard',
#   'disaster',
#   'film',
#   'procedures',
#   ',',
#   'but',
#   'there',
#   'is',
#   'one',
#   'subplot',
#   'worth',
#   'mentioning',
#   '.',
#   'jenny',
#   'and',
#   'her',
#   'father',
#   ',',
#   'jason',
#   '(',
#   'maximilian',
#   'schell',
#   ')',
#   ',',
#   'have',
#   'a',
#   'very',
#   'touching',
#   'relationship',
#   'that',
#   'forms',
#   'out',
#   'of',
#   'the',
#   'impending',
#   'doom',
#   '.',
#   'the',
#   'final',
#   'moment',
#   'involving',
#   'the',
#   'two',
#   'characters',
#   'is',
#   'heartfelt',
#   'and',
#   'emotional',
#   '.',
#   'it',
#   "'",
#   's',
#   'a',
#   'shame',
#   'that',
#   'nothing',
#   'else',
#   'is',
#   'heartfelt',
#   '.',
#   'now',
#   ',',
#   'of',
#   'course',
#   ',',
#   'we',
#   'all',
#   'know',
#   'that',
#   'the',
#   'comet',
#   'does',
#   'impact',
#   'the',
#   'surface',
#   '.',
#   'the',
#   'title',
#   'alone',
#   'suggests',
#   'it',
#   ',',
#   'and',
#   'the',
#   'previews',
#   'actually',
#   'show',
#   'it',
#   '!',
#   'by',
#   'doing',
#   'this',
#   ',',
#   'absoltuely',
#   'no',
#   'tension',
#   'can',
#   'be',
#   'drawn',
#   'from',
#   'any',
#   'attempt',
#   'to',
#   'stop',
#   'the',
#   'comet',
#   'because',
#   'we',
#   'all',
#   'know',
#   'that',
#   'it',
#   'won',
#   "'",
#   't',
#   'work',
#   '.',
#   'director',
#   'mimi',
#   'leder',
#   'came',
#   'from',
#   'her',
#   'successful',
#   'tries',
#   'at',
#   'direction',
#   'with',
#   'episodes',
#   'of',
#   'the',
#   'hit',
#   'television',
#   'show',
#   '"',
#   'er',
#   '.',
#   '"',
#   'her',
#   'major',
#   'film',
#   'debut',
#   'was',
#   'the',
#   'peacemaker',
#   ',',
#   'a',
#   'pathetic',
#   'and',
#   'heartless',
#   'action',
#   'film',
#   '.',
#   'well',
#   ',',
#   'this',
#   'time',
#   'leder',
#   'outdid',
#   'herself',
#   ',',
#   'creating',
#   'a',
#   'film',
#   'worse',
#   'than',
#   'that',
#   'one',
#   '.',
#   'suggestion',
#   'to',
#   'ms',
#   '.',
#   'leder',
#   ':',
#   'please',
#   ',',
#   'stay',
#   'away',
#   'from',
#   'the',
#   'big',
#   'screen',
#   ',',
#   'or',
#   'at',
#   'least',
#   'the',
#   'action',
#   'genre',
#   '.',
#   'much',
#   'of',
#   'the',
#   ...])

# %% [markdown]
# ### applying function on all reviews

# %%
featureset = [(search_features(doc), category) for (doc, category) in docs]

# %%
len(featureset[100][0])
# Out:
# 3000

# %% [markdown]
# ## Train/Test

# %%
training_set = featureset[:1600]
testing_set = featureset[1600:]

# %%
train_neg_total = 0
train_pos_total = 0
test_neg_total = 0
test_pos_total = 0

for item in training_set:
    category = item[1]
    if category == 'neg':
        train_neg_total = train_neg_total + 1
    else:
        train_pos_total = train_pos_total + 1
        
for item in testing_set:
    category = item[1]
    if category == 'neg':
        test_neg_total = test_neg_total + 1
    else:
        test_pos_total = test_pos_total + 1
        
print('Train total pos:', train_pos_total)
print('Train total neg:', train_neg_total)
print('Train Ratio:', (train_neg_total/train_pos_total),':',train_pos_total/train_pos_total)

print('\n')
print('Test total pos:', test_pos_total)
print('Test total neg:', test_neg_total)
# print('Test Ratio:', (test_pos_total/test_neg_total),':',test_neg_total/test_neg_total)
# Out:
# Train total pos: 600
# Train total neg: 1000
# Train Ratio: 1.6666666666666667 : 1.0
#
#
# Test total pos: 400
# Test total neg: 0

# %%
classifier = nltk.NaiveBayesClassifier.train(training_set)

# %%
print('Classifier accuracy is - testing: {}'.format(nltk.classify.accuracy(classifier, testing_set)*100))
print('Classifier accuracy is - training: {}'.format(nltk.classify.accuracy(classifier, training_set)*100))
# Out:
# Classifier accuracy is - testing: 73.75
# Classifier accuracy is - training: 90.25

# %% [markdown]
# ## Using top-60 as feedback loop into the model to train even better

# %%
top60 = classifier.most_informative_features(60)

newWords = []
for v in top60:
    newWords.append(v[0])
    
newWords
# Out:
# ['ludicrous',
#  'outstanding',
#  'mulan',
#  'inept',
#  'whatsoever',
#  'seagal',
#  'idiotic',
#  'damon',
#  'finest',
#  'freddie',
#  'wonderfully',
#  'prinze',
#  'anger',
#  'breathtaking',
#  'flynt',
#  'lame',
#  'henstridge',
#  'waste',
#  'wasted',
#  'garbage',
#  'inane',
#  'awful',
#  'beautifully',
#  'poorly',
#  'thompson',
#  'ripley',
#  'tucker',
#  'mess',
#  'refreshing',
#  'bother',
#  'era',
#  'pointless',
#  'worst',
#  'laughable',
#  'tedious',
#  'schumacher',
#  'allows',
#  'fantastic',
#  'stupid',
#  'zero',
#  'uninteresting',
#  'nomination',
#  'alicia',
#  'ridiculous',
#  'bland',
#  'fits',
#  'unfunny',
#  'sat',
#  'portrayal',
#  'patch',
#  'lebowski',
#  'jedi',
#  'hank',
#  'terrific',
#  'mature',
#  'religion',
#  'italian',
#  'lifeless',
#  'gon',
#  'terrible']

# %% [markdown]
# ## Save a model

# %%
import pickle

# %%
save_classifier = open('naive_bayes_model.pkl',"wb")
pickle.dump(classifier, save_classifier)
save_classifier.close()

# %% [markdown]
# ### Get model file back

# %%
classifier_f = open('naive_bayes_model.pkl','rb')
classifier = pickle.load(classifier_f)
classifier_f.close()

# %% [markdown]
# ## Trying the model

# %%
from nltk import word_tokenize

# %%
custom_review = "I bad the restaurant. It was a disaster eating there. Poor service."
custom_tokens = word_tokenize(custom_review)
custom_review_set = search_features(custom_tokens)

# %%
print(classifier.classify(custom_review_set))
# Out:
# neg

# %%
prob_res = classifier.prob_classify(custom_review_set)
print(prob_res.max())
print(prob_res.prob('pos'))
print(prob_res.prob('neg'))
# Out:
# neg
# 1.2733017053383622e-06
# 0.9999987266982958

# %% [markdown]
# ________________________________________________________
